# %% [markdown]
# <a href="https://colab.research.google.com/github/dan9133/Bharat_Intern_Titanic_Classification_Analysis/blob/main/Titanic_projetct_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Objective:- In this article, I will focus on importing datasets, dealing with missing values, changing data types, filtering, sorting, selecting specific column(s), dealing with duplicate values, dropping and adding rows and columns, counting values, counting unique values**

# %%
# import pandas
import pandas as pd

# %%
df=pd.read_csv("/content/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# **Checking last elements of the DataFrame with .tail() method**
#
# **There is also a method to see the see last n number of elements. The method is called .tail()**

# %%
df.tail(25)
# Out:
#      PassengerId  Survived  Pclass  \
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# ...

# %% [markdown]
# **Reading a CSV file with specific columns**
# **with just PassengerId, Survived, Pclass columns**

# %%
#df=pd.read_csv("/content/train.csv",usecols=["PassengerId","Survived","Pclass"])
#df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df1=df[["PassengerId","Survived","Pclass"]]
df1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %% [markdown]
# **describe() method
# This method is used to get a summary of numeric values in your dataset. It calculates the mean, standard deviation, minimum value, maximum value**

# %%
#df.describe()
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# **info() method:-
# This method prints information about a DataFrame including the index dtype and column dtypes**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# display the dtype
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# **Sorting the DataFrame based on a column**

# %%
df.sort_values("Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values("Fare").head(10)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 597          598         0       3              Johnson, Mr. Alfred  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 277          278         0       2      Parkes, Mr. Francis "Frank"  male
# 413          414         0       2   Cunningham, Mr. Alfred Fleming  male
# 674          675         0       2       Watson, Mr. Ennis Hastings  male
# 263          264         0       1            Harrison, Mr. William  male
# 466          467         0       2            Campbell, Mr. William  male
# 732          733         0       2             Knight, Mr. Robert J  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 271  25.0      0      0    LINE   0.0   NaN        S
# ...

# %% [markdown]
# **We have to set the ascending argument as False. But using .tail()**

# %%
#df.sort_values("Fare",ascending=False).head()
df.sort_values('Fare',ascending=False).head(10)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 118          119         0       1               Baxter, Mr. Quigg Edmond
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
df.sort_values('Fare',ascending=False, inplace=True)
df.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S

# %% [markdown]
# **Sorting columns with strings**

# %%
df.sort_values('Fare',ascending=False,na_position='last')
df.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S

# %%
df.sort_values("Cabin",ascending=False,na_position='first')
df.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S

# %%
df.sort_values("Cabin",ascending=False,na_position='last')
df.tail(20)
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 818          819         0       3  Holm, Mr. John Fredrik Alexander  male
# 843          844         0       3        Lemberopolous, Mr. Peter L  male
# 326          327         0       3         Nysveen, Mr. Johan Hansen  male
# 872          873         0       1          Carlsson, Mr. Frans Olof  male
# 378          379         0       3               Betros, Mr. Tannous  male
# 179          180         0       3               Leonard, Mr. Lionel  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 815          816         0       1                  Fry, Mr. Richard  male
# ...

# %% [markdown]
# **Using .value_counts() to count the occurences of each variable in a column**

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# **Using .nunique() to count number of unique values that occur in dataset or in a column**

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# **count the unique records with .nunique() for a column.**

# %%
#df['Sex'].nunique()
df[['Sex','Ticket']].nunique()
# Out:
# Sex         2
# Ticket    681
# dtype: int64

# %% [markdown]
# **Changing the data type**

# %%
df["Embarked"]=df["Embarked"].astype("category")
df["Embarked"].dtype
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %% [markdown]
# **Filtering under one condition**

# %%
df['Embarked'] =="C"
# Out:
# 258     True
# 679     True
# 737     True
# 88     False
# 438    False
#        ...
# 277    False
# 271    False
# 597    False
# 466    False
# 674    False
# Name: Embarked, Length: 891, dtype: bool

# %%
#df["Embarked"] =="C"
df["Embarked"] .head(5)
# Out:
# 258    C
# 679    C
# 737    C
# 88     S
# 438    S
# Name: Embarked, dtype: category
# Categories (3, object): ['C', 'Q', 'S']

# %% [markdown]
# **What if we dont want to see just Trues and Falses? What if we want to see all information of those whose Embarked is C**

# %%
df[df['Embarked']=='C']
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 311          312         1       1             Ryerson, Miss. Emily Borie
# ..           ...       ...     ...                                    ...
# 553          554         1       3      Leeni, Mr. Fahim ("Philip Zenni")
# 598          599         0       3                      Boulos, Mr. Hanna
# 244          245         0       3                   Attalah, Mr. Sleiman
# 843          844         0       3             Lemberopolous, Mr. Peter L
# 378          379         0       3                    Betros, Mr. Tannous
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
# Another Way
E_df=df['Embarked']=='C'
df[E_df]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 311          312         1       1             Ryerson, Miss. Emily Borie
# ..           ...       ...     ...                                    ...
# 553          554         1       3      Leeni, Mr. Fahim ("Philip Zenni")
# 598          599         0       3                      Boulos, Mr. Hanna
# 244          245         0       3                   Attalah, Mr. Sleiman
# 843          844         0       3             Lemberopolous, Mr. Peter L
# 378          379         0       3                    Betros, Mr. Tannous
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
# not print C
df[df['Embarked']!='C']
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 88            89         1       1      Fortune, Miss. Mabel Helen  female
# 438          439         0       1               Fortune, Mr. Mark    male
# 27            28         0       1  Fortune, Mr. Charles Alexander    male
# 341          342         1       1  Fortune, Miss. Alice Elizabeth  female
# 527          528         0       1              Farthing, Mr. John    male
# ..           ...       ...     ...                             ...     ...
# 277          278         0       2     Parkes, Mr. Francis "Frank"    male
# 271          272         1       3    Tornquist, Mr. William Henry    male
# 597          598         0       3             Johnson, Mr. Alfred    male
# 466          467         0       2           Campbell, Mr. William    male
# 674          675         0       2      Watson, Mr. Ennis Hastings    male
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# **Filtering under two or more condition**

# %%
df_fare=df['Fare']<100
df_gender=df['Sex']=="female"
df[df_fare & df_gender]
# Out:
#      PassengerId  Survived  Pclass  \
# 820          821         1       1
# 520          521         1       1
# 291          292         1       1
# 486          487         1       1
# 412          413         1       1
# ..           ...       ...     ...
# 780          781         1       3
# 367          368         1       3
# 875          876         1       3
# 19            20         1       3
# 654          655         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 520                              Perreault, Miss. Anne  female  30.0      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1
# 486    Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 412                             Minahan, Miss. Daisy E  female  33.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_fare=df['Fare']<=100
df_gender=df['Sex']=="female"
df[df_fare | df_gender]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 311          312         1       1             Ryerson, Miss. Emily Borie
# ..           ...       ...     ...                                    ...
# 277          278         0       2            Parkes, Mr. Francis "Frank"
# 271          272         1       3           Tornquist, Mr. William Henry
# 597          598         0       3                    Johnson, Mr. Alfred
# 466          467         0       2                  Campbell, Mr. William
# 674          675         0       2             Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %% [markdown]
# **Finding the null values with .isnull()**

# %%
df_null=df['Cabin'].isnull()
df[df_null]
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 557          558         0       1
# 380          381         1       1
# 856          857         1       1
# 708          709         1       1
# ..           ...       ...     ...
# 277          278         0       2
# 271          272         1       3
# 597          598         0       3
# 466          467         0       2
# 674          675         0       2
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 258                            Ward, Miss. Anna  female  35.0      0      0
# 557                         Robbins, Mr. Victor    male   NaN      0      0
# 380                       Bidois, Miss. Rosalie  female  42.0      0      0
# 856  Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1      1
# 708                        Cleaver, Miss. Alice  female  22.0      0      0
# ..                                          ...     ...   ...    ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Dealing with missing values**

# %%
# Droping Columns:
df.drop(labels=['Cabin'],axis=1).head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 258  female  35.0      0      0  PC 17755  512.3292        C
# 679    male  36.0      0      1  PC 17755  512.3292        C
# 737    male  35.0      0      0  PC 17755  512.3292        C
# 88   female  23.0      3      2     19950  263.0000        S
# 438    male  64.0      1      4     19950  263.0000        S

# %%
# more columns Drop
df.drop(labels=['Cabin','Sex'],axis=1).head()
# Out:
#      PassengerId  Survived  Pclass                                Name   Age  \
# 258          259         1       1                    Ward, Miss. Anna  35.0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  36.0
# 737          738         1       1              Lesurer, Mr. Gustave J  35.0
# 88            89         1       1          Fortune, Miss. Mabel Helen  23.0
# 438          439         0       1                   Fortune, Mr. Mark  64.0
#
#      SibSp  Parch    Ticket      Fare Embarked
# 258      0      0  PC 17755  512.3292        C
# 679      0      1  PC 17755  512.3292        C
# 737      0      0  PC 17755  512.3292        C
# 88       3      2     19950  263.0000        S
# 438      1      4     19950  263.0000        S

# %% [markdown]
# **Filling missing values with .fillna()
# To fill missing values in a dataframe, there is a method called .fillna()**

# %%
#df["Age"].fillna("unknown", inplace=True)

# %%
mean_fill = df.fillna(df.mean())  # Fill missing values with column means
median_fill = df.fillna(df.median())  # Fill missing values with column medians
# Out:
# <ipython-input-131-125933db19c9>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_fill = df.fillna(df.mean())  # Fill missing values with column means
# <ipython-input-131-125933db19c9>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_fill = df.fillna(df.median())  # Fill missing values with column medians

# %%
fill_values = {'column1': 0, 'column2': 'N/A'}
custom_filled_df = df.fillna(value=fill_values)
